# %%
print("Hi Genius")
# Out:
# Hi Genius

# %%
import pandas as pd
df = pd.read_csv('indian_liver_patient.csv')

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'Age': 65,
#   'Gender': 'Female',
#   'Total_Bilirubin': 0.7,
#   'Direct_Bilirubin': 0.1,
#   'Alkaline_Phosphotase': 187,
#   'Alamine_Aminotransferase': 16,
#   'Aspartate_Aminotransferase': 18,
#   'Total_Protiens': 6.8,
#   'Albumin': 3.3,
#   'Albumin_and_Globulin_Ratio': 0.9,
#   'Dataset': 1},
#  {'Age': 62,
#   'Gender': 'Male',
#   'Total_Bilirubin': 10.9,
#   'Direct_Bilirubin': 5.5,
#   'Alkaline_Phosphotase': 699,
#   'Alamine_Aminotransferase': 64,
#   'Aspartate_Aminotransferase': 100,
#   'Total_Protiens': 7.5,
#   'Albumin': 3.2,
#   'Albumin_and_Globulin_Ratio': 0.74,
#   'Dataset': 1},
#  {'Age': 62,
#   'Gender': 'Male',
#   'Total_Bilirubin': 7.3,
#   'Direct_Bilirubin': 4.1,
#   'Alkaline_Phosphotase': 490,
#   'Alamine_Aminotransferase': 60,
#   'Aspartate_Aminotransferase': 68,
#   'Total_Protiens': 7.0,
#   'Albumin': 3.3,
#   'Albumin_and_Globulin_Ratio': 0.89,
#   'Dataset': 1},
#  {'Age': 58,
#   'Gender': 'Male',
#   'Total_Bilirubin': 1.0,
# ...

# %%
DB_NAME="INDIA_LIVER"
COLLECTION_NAME="liver_patient_data"
CONNECTION_URL ="mongodb+srv://user:pass@cluster0.uqgnywy.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
#!pip install pymongo[srv]

# %%
import certifi
import pymongo
client = pymongo.MongoClient(CONNECTION_URL, ssl_ca_certs=certifi.where())
# TO CREATE THE DATABASE
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]
# TO INSERT DATA INTO THE COLLECTION
rec = collection.insert_many(data)

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"], axis=1)

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...
